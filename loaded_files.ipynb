# %%
import pandas as pd
import json

# %%
ufo_file = "Resources/ufo.csv"
ufo_df = pd.read_csv(ufo_file)
ufo_df.head()
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# 3  My older brother and twin sister were leaving ...   1/17/2004  28.9783333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004  21.4180556
#
#    longitude
# 0  -97.941111
# 1  -98.581082
# 2   -2.916667
# 3  -96.645833
# 4 -157.803611

# %%
econ_growth = "Resources/us_econ_growth.csv"
econ_df = pd.read_csv(econ_growth)

# %%
cig_file = "Resources/sales-of-cigarettes-per-adult-per-day.csv"
cig_df = pd.read_csv(cig_file)
# cig_df

# %%
with open('Resources/presidents_debt.json') as json_data:
    pres_debt = json.load(json_data)
    #print(cig_data)
    
print(json.dumps(pres_debt, indent=4, sort_keys=True))
# Out:
# {
#     "data": {
#         "by_president": [
#             {
#                 "age": 88,
#                 "date_born_epoch": -2702833200,
#                 "date_died_epoch": 94197600,
#                 "name": "Harry S. Truman",
#                 "number": 33,
#                 "party": "Democratic",
#                 "term_debt_increase_pct": 28.9,
#                 "term_end_epoch": -534794400,
#                 "term_start_epoch": -780174000
#             },
#             {
#                 "age": 78,
#                 "date_born_epoch": -2499793200,
#                 "date_died_epoch": -24087600,
#                 "name": "Dwight D. Eisenhower",
#                 "number": 34,
#                 "party": "Republican",
#                 "term_debt_increase_pct": 10.5,
#                 "term_end_epoch": -282333600,
#                 "term_start_epoch": -534794400
#             },
#             {
#                 "age": 46,
#                 "date_born_epoch": -1659726000,
#                 "date_died_epoch": -192823200,
#                 "name": "John F. Kennedy",
#                 "number": 35,
#                 "party": "Democratic",
#                 "term_debt_increase_pct": 6.8,
#                 "term_end_epoch": -192823200,
#                 "term_start_epoch": -282333600
#             },
#             {
#                 "age": 64,
#                 "date_born_epoch": -1935946800,
#                 "date_died_epoch": 96530400,
#                 "name": "Lyndon B. Johnson",
#                 "number": 36,
#                 "party": "Democratic",
#                 "term_debt_increase_pct": 13.6,
#                 "term_end_epoch": -29872800,
#                 "term_start_epoch": -192823200
#             },
#             {
#                 "age": 81,
#                 "date_born_epoch": -1798048800,
#                 "date_died_epoch": 766990800,
#                 "name": "Richard Nixon",
#                 "number": 37,
#                 "party": "Republican",
#                 "term_debt_increase_pct": 31.8,
#                 "term_end_epoch": 145256400,
#                 "term_start_epoch": -29872800
#             },
#             {
#                 "age": 93,
#                 "date_born_epoch": -1781982000,
#                 "date_died_epoch": 1167112800,
#                 "name": "Gerald Ford",
#                 "number": 38,
#                 "party": "Republican",
#                 "term_debt_increase_pct": 35.4,
#                 "term_end_epoch": 222588000,
#                 "term_start_epoch": 145256400
#             },
#             {
#                 "age": 91,
#                 "date_born_epoch": 1001912400,
#                 "date_died_epoch": -33008580000,
#                 "name": "Jimmy Carter",
#                 "number": 39,
#                 "party": "Democratic",
#                 "term_debt_increase_pct": 46.3,
#                 "term_end_epoch": 348818400,
#                 "term_start_epoch": 222588000
#             },
#             {
#                 "age": 93,
#                 "date_born_epoch": -1858788000,
#                 "date_died_epoch": 1086411600,
#                 "name": "Ronald Reagan",
#                 "number": 40,
#                 "party": "Republican",
#                 "term_debt_increase_pct": 186.7,
#                 "term_end_epoch": 601279200,
#                 "term_start_epoch": 348818400
#             },
#             {
#                 "age": 91,
#                 "date_born_epoch": -1437591600,
#                 "date_died_epoch": null,
#                 "name": "George H. W. Bush",
#                 "number": 41,
#                 "party": "Republican",
#                 "term_debt_increase_pct": 56.2,
#                 "term_end_epoch": 727509600,
#                 "term_start_epoch": 601279200
#             },
#             {
#                 "age": 69,
#                 "date_born_epoch": -737492400,
#                 "date_died_epoch": null,
#                 "name": "Bill Clinton",
#                 "number": 42,
#                 "party": "Democratic",
#                 "term_debt_increase_pct": 39.6,
#                 "term_end_epoch": 979970400,
#                 "term_start_epoch": 727509600
#             },
#             {
#                 "age": 69,
#                 "date_born_epoch": -741294000,
#                 "date_died_epoch": null,
#                 "name": "George W. Bush",
#                 "number": 43,
#                 "party": "Republican",
#                 "term_debt_increase_pct": 76.7,
#                 "term_end_epoch": 1232431200,
#                 "term_start_epoch": 979970400
#             },
#             {
#                 "age": 54,
#                 "date_born_epoch": -265402800,
#                 "date_died_epoch": null,
#                 "name": "Barack Obama",
#                 "number": 44,
#                 "party": "Democratic",
#                 "term_debt_increase_pct": 87.8,
#                 "term_end_epoch": 1484892000,
#                 "term_start_epoch": 1232431200
#             }
#         ],
#         "by_year": [
#             {
#                 "annual_debt_increase_pct": 0.2,
#                 "party": "Democratic",
#                 "president": "Harry S. Truman",
#                 "year": 1949
#             },
#             {
#                 "annual_debt_increase_pct": 1.8,
#                 "party": "Democratic",
#                 "president": "Harry S. Truman",
#                 "year": 1950
#             },
#             {
#                 "annual_debt_increase_pct": -0.8,
#                 "party": "Democratic",
#                 "president": "Harry S. Truman",
#                 "year": 1951
#             },
#             {
#                 "annual_debt_increase_pct": 1.5,
#                 "party": "Democratic",
#                 "president": "Harry S. Truman",
#                 "year": 1952
#             },
#             {
#                 "annual_debt_increase_pct": 2.7,
#                 "party": "Republican",
#                 "president": "Dwight D. Eisenhower",
#                 "year": 1953
#             },
#             {
#                 "annual_debt_increase_pct": 2.0,
#                 "party": "Republican",
#                 "president": "Dwight D. Eisenhower",
#                 "year": 1954
#             },
#             {
#                 "annual_debt_increase_pct": 1.1,
#                 "party": "Republican",
#                 "president": "Dwight D. Eisenhower",
#                 "year": 1955
#             },
#             {
#                 "annual_debt_increase_pct": -0.6,
#                 "party": "Republican",
#                 "president": "Dwight D. Eisenhower",
#                 "year": 1956
#             },
#             {
#                 "annual_debt_increase_pct": -0.8,
#                 "party": "Republican",
#                 "president": "Dwight D. Eisenhower",
#                 "year": 1957
#             },
#             {
#                 "annual_debt_increase_pct": 2.1,
#                 "party": "Republican",
#                 "president": "Dwight D. Eisenhower",
#                 "year": 1958
#             },
#             {
#                 "annual_debt_increase_pct": 3.0,
#                 "party": "Republican",
#                 "president": "Dwight D. Eisenhower",
#                 "year": 1959
#             },
#             {
#                 "annual_debt_increase_pct": 0.6,
#                 "party": "Republican",
#                 "president": "Dwight D. Eisenhower",
#                 "year": 1960
#             },
#             {
#                 "annual_debt_increase_pct": 0.9,
#                 "party": "Democratic",
#                 "president": "John F. Kennedy",
#                 "year": 1961
#             },
#             {
#                 "annual_debt_increase_pct": 3.2,
#                 "party": "Democratic",
#                 "president": "John F. Kennedy",
#                 "year": 1962
#             },
#             {
#                 "annual_debt_increase_pct": 2.6,
#                 "party": "Democratic",
#                 "president": "John F. Kennedy",
#                 "year": 1963
#             },
#             {
#                 "annual_debt_increase_pct": 1.9,
#                 "party": "Democratic",
#                 "president": "Lyndon B. Johnson",
#                 "year": 1964
#             },
#             {
#                 "annual_debt_increase_pct": 1.8,
#                 "party": "Democratic",
#                 "president": "Lyndon B. Johnson",
#                 "year": 1965
#             },
#             {
#                 "annual_debt_increase_pct": 0.8,
#                 "party": "Democratic",
#                 "president": "Lyndon B. Johnson",
#                 "year": 1966
#             },
#             {
#                 "annual_debt_increase_pct": 2.0,
#                 "party": "Democratic",
#                 "president": "Lyndon B. Johnson",
#                 "year": 1967
#             },
#             {
#                 "annual_debt_increase_pct": 6.5,
#                 "party": "Democratic",
#                 "president": "Lyndon B. Johnson",
#                 "year": 1968
#             },
#             {
#                 "annual_debt_increase_pct": 1.8,
#                 "party": "Republican",
#                 "president": "Richard Nixon",
#                 "year": 1969
#             },
#             {
#                 "annual_debt_increase_pct": 4.9,
#                 "party": "Republican",
#                 "president": "Richard Nixon",
#                 "year": 1970
#             },
#             {
#                 "annual_debt_increase_pct": 7.3,
#                 "party": "Republican",
#                 "president": "Richard Nixon",
#                 "year": 1971
#             },
#             {
#                 "annual_debt_increase_pct": 7.3,
#                 "party": "Republican",
#                 "president": "Richard Nixon",
#                 "year": 1972
#             },
#             {
#                 "annual_debt_increase_pct": 7.2,
#                 "party": "Republican",
#                 "president": "Richard Nixon",
#                 "year": 1973
#             },
#             {
#                 "annual_debt_increase_pct": 3.7,
#                 "party": "Republican",
#                 "president": "Gerald Ford",
#                 "year": 1974
#             },
#             {
#                 "annual_debt_increase_pct": 12.2,
#                 "party": "Republican",
#                 "president": "Gerald Ford",
#                 "year": 1975
#             },
#             {
#                 "annual_debt_increase_pct": 16.4,
#                 "party": "Republican",
#                 "president": "Gerald Ford",
#                 "year": 1976
#             },
#             {
#                 "annual_debt_increase_pct": 12.6,
#                 "party": "Democratic",
#                 "president": "Jimmy Carter",
#                 "year": 1977
#             },
#             {
#                 "annual_debt_increase_pct": 10.4,
#                 "party": "Democratic",
#                 "president": "Jimmy Carter",
#                 "year": 1978
#             },
#             {
#                 "annual_debt_increase_pct": 7.1,
#                 "party": "Democratic",
#                 "president": "Jimmy Carter",
#                 "year": 1979
#             },
#             {
#                 "annual_debt_increase_pct": 9.8,
#                 "party": "Democratic",
#                 "president": "Jimmy Carter",
#                 "year": 1980
#             },
#             {
#                 "annual_debt_increase_pct": 9.9,
#                 "party": "Republican",
#                 "president": "Ronald Reagan",
#                 "year": 1981
#             },
#             {
#                 "annual_debt_increase_pct": 14.4,
#                 "party": "Republican",
#                 "president": "Ronald Reagan",
#                 "year": 1982
#             },
#             {
#                 "annual_debt_increase_pct": 20.6,
#                 "party": "Republican",
#                 "president": "Ronald Reagan",
#                 "year": 1983
#             },
#             {
#                 "annual_debt_increase_pct": 14.2,
#                 "party": "Republican",
#                 "president": "Ronald Reagan",
#                 "year": 1984
#             },
#             {
#                 "annual_debt_increase_pct": 16.0,
#                 "party": "Republican",
#                 "president": "Ronald Reagan",
#                 "year": 1985
#             },
#             {
#                 "annual_debt_increase_pct": 16.6,
#                 "party": "Republican",
#                 "president": "Ronald Reagan",
#                 "year": 1986
#             },
#             {
#                 "annual_debt_increase_pct": 10.6,
#                 "party": "Republican",
#                 "president": "Ronald Reagan",
#                 "year": 1987
#             },
#             {
#                 "annual_debt_increase_pct": 10.7,
#                 "party": "Republican",
#                 "president": "Ronald Reagan",
#                 "year": 1988
#             },
#             {
#                 "annual_debt_increase_pct": 9.8,
#                 "party": "Republican",
#                 "president": "George H. W. Bush",
#                 "year": 1989
#             },
#             {
#                 "annual_debt_increase_pct": 13.2,
#                 "party": "Republican",
#                 "president": "George H. W. Bush",
#                 "year": 1990
#             },
#             {
#                 "annual_debt_increase_pct": 13.4,
#                 "party": "Republican",
#                 "president": "George H. W. Bush",
#                 "year": 1991
#             },
#             {
#                 "annual_debt_increase_pct": 10.9,
#                 "party": "Republican",
#                 "president": "George H. W. Bush",
#                 "year": 1992
#             },
#             {
#                 "annual_debt_increase_pct": 8.5,
#                 "party": "Democratic",
#                 "president": "Bill Clinton",
#                 "year": 1993
#             },
#             {
#                 "annual_debt_increase_pct": 6.4,
#                 "party": "Democratic",
#                 "president": "Bill Clinton",
#                 "year": 1994
#             },
#             {
#                 "annual_debt_increase_pct": 6.0,
#                 "party": "Democratic",
#                 "president": "Bill Clinton",
#                 "year": 1995
#             },
#             {
#                 "annual_debt_increase_pct": 5.0,
#                 "party": "Democratic",
#                 "president": "Bill Clinton",
#                 "year": 1996
#             },
#             {
#                 "annual_debt_increase_pct": 3.6,
#                 "party": "Democratic",
#                 "president": "Bill Clinton",
#                 "year": 1997
#             },
#             {
#                 "annual_debt_increase_pct": 2.1,
#                 "party": "Democratic",
#                 "president": "Bill Clinton",
#                 "year": 1998
#             },
#             {
#                 "annual_debt_increase_pct": 2.4,
#                 "party": "Democratic",
#                 "president": "Bill Clinton",
#                 "year": 1999
#             },
#             {
#                 "annual_debt_increase_pct": 0.3,
#                 "party": "Democratic",
#                 "president": "Bill Clinton",
#                 "year": 2000
#             },
#             {
#                 "annual_debt_increase_pct": 2.3,
#                 "party": "Republican",
#                 "president": "George W. Bush",
#                 "year": 2001
#             },
#             {
#                 "annual_debt_increase_pct": 7.2,
#                 "party": "Republican",
#                 "president": "George W. Bush",
#                 "year": 2002
#             },
#             {
#                 "annual_debt_increase_pct": 8.9,
#                 "party": "Republican",
#                 "president": "George W. Bush",
#                 "year": 2003
#             },
#             {
#                 "annual_debt_increase_pct": 8.8,
#                 "party": "Republican",
#                 "president": "George W. Bush",
#                 "year": 2004
#             },
#             {
#                 "annual_debt_increase_pct": 7.5,
#                 "party": "Republican",
#                 "president": "George W. Bush",
#                 "year": 2005
#             },
#             {
#                 "annual_debt_increase_pct": 7.2,
#                 "party": "Republican",
#                 "president": "George W. Bush",
#                 "year": 2006
#             },
#             {
#                 "annual_debt_increase_pct": 5.9,
#                 "party": "Republican",
#                 "president": "George W. Bush",
#                 "year": 2007
#             },
#             {
#                 "annual_debt_increase_pct": 11.3,
#                 "party": "Republican",
#                 "president": "George W. Bush",
#                 "year": 2008
#             },
#             {
#                 "annual_debt_increase_pct": 18.8,
#                 "party": "Democratic",
#                 "president": "Barack Obama",
#                 "year": 2009
#             },
#             {
#                 "annual_debt_increase_pct": 13.9,
#                 "party": "Democratic",
#                 "president": "Barack Obama",
#                 "year": 2010
#             },
#             {
#                 "annual_debt_increase_pct": 9.1,
#                 "party": "Democratic",
#                 "president": "Barack Obama",
#                 "year": 2011
#             },
#             {
#                 "annual_debt_increase_pct": 8.6,
#                 "party": "Democratic",
#                 "president": "Barack Obama",
#                 "year": 2012
#             },
#             {
#                 "annual_debt_increase_pct": 4.2,
#                 "party": "Democratic",
#                 "president": "Barack Obama",
#                 "year": 